# %%
import pandas as pd

df = pd.read_json("https://dluberprojectvinamra.blob.core.windows.net/raw/ingestion/map_cities.json?sp=r&st=2026-06-09T06:12:56Z&se=2026-06-10T14:27:56Z&spr=https&sv=2026-02-06&sr=c&sig=4IcJSzrDbWNozX4nd2VLyY%2FT%2F56AZmGPhxu%2Fd%2B%2BFjxQ%3D")
                  
df_spark = spark.createDataFrame(df)

display(df_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import pandas as pd

files = [
{"file":"map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]

for file in files:
    url = f"https://dluberprojectvinamra.blob.core.windows.net/raw/ingestion/{file['file']}.json?sp=r&st=2026-06-09T06:12:56Z&se=2026-06-10T14:27:56Z&spr=https&sv=2026-02-06&sr=c&sig=4IcJSzrDbWNozX4nd2VLyY%2FT%2F56AZmGPhxu%2Fd%2B%2BFjxQ%3D"

    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)

    #Writing Data to Bronze Layer
    df_spark.write.format("delta")\
        .mode("overwrite")\
        .option("overwriteSchema", "true")\
        .saveAsTable(f"uber.bronze.{file['file']}")

# %%
url = "https://dluberprojectdev.blob.core.windows.net/raw/ingestion/bulk_rides.json?"

df = pd.read_json(url)
df_spark = spark.createDataFrame(df)
if not spark.catalog.tableExists("uber.bronze.bulk_rides"):
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uber.bronze.bulk_rides")

# %%
# %sql

SELECT * FROM uber.bronze.map_cities
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
